# %%
import os
os.environ['USE_PYGEOS'] = '0'
import sys
import numpy
import pandas
pandas.options.mode.chained_assignment = None  # default='warn'
from datetime import datetime, timedelta
import pytz
import geopandas
import dask_geopandas
import json
from glob import glob
import time

sys.path.insert(1, os.path.abspath("../.."))
from qtree_index import nestedgrid, mortoncurve
from vectorstore import vectorstore

import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Initialize a dataset

# %%
# %%time
dataset = 'ne_10m_admin2_counties'
collection_id = 'vector-ne-10m-admin2-counties'

# Stac collection title
collection_title = 'Natural Earth Counties'

# Stac collection description
description = '''Natural Earth (ne) Admin 2 (county-level) data.'''

# Parquet file custom metadata
custom_meta_content = {'About': description}

dt_col = 'timestamp'
geom_col = 'geometry'  # Needs to be called 'geometry'
id_col = 'ADM2_CODE'
dimension_values = {}

# temporal_keys = [] #['year']
# temporal_partitions = [] #['year']

max_level = 26
target_level = 14
max_depth = 14
max_inflation = 100 #None
target_rows = 1e6

grid = nestedgrid.World(4326)
# Create or initialize an existing GeoDN vectorstore
vs = vectorstore.Vectorstore(
    dataset=dataset,
    collection_id=collection_id,
    dimension_values=dimension_values,
    grid=grid,
    dt_col=dt_col,
    geom_col=geom_col,
    id_col=id_col,
    max_level=max_level,
    target_level=target_level,
    max_depth=max_depth,
    max_inflation=max_inflation,
    target_rows=target_rows,
    custom_meta_content=custom_meta_content,
    verbose=True,
)

vs.write_metadata()
vs.read_metadata()

filepath = '/data/vector/ne_10m_cultural/10m_cultural/ne_10m_admin_2_counties.shp'
gdf_complete = geopandas.read_file(filepath)
gdf_complete[dt_col] = datetime(2022, 5, 12, tzinfo=pytz.utc)

assert(~gdf_complete[id_col].duplicated().any())

gdf_complete.tail(2)
# Out:
# CPU times: total: 1.81 s
# Wall time: 2.55 s
#               FEATURECLA  SCALERANK  ADM2_CODE ISO_3166_2 ISO_A2  ADM0_SR  \
# 3222  Admin-2 scale rank          0  USA-72121      US-72     US        1
# 3223  Admin-2 scale rank          0  USA-72093      US-72     US        1
#
#                NAME                 NAME_ALT NAME_LOCAL       TYPE  ...  \
# 3222  Sabana Grande  Sabana Grande Municipio       None  Municipio  ...
# 3223        Maricao        Maricao Municipio       None  Municipio  ...
#
#      NAME_RU NAME_SV NAME_TR        NAME_UK                   NAME_UR  \
# 3222    None    None    None  Сабана-Гранде  سبانہ گراندے، پورٹو ریکو
# 3223    None    None    None        Марікао       ماریکاو، پورٹو ریکو
#
#       NAME_VI  NAME_ZH  NAME_ZHT  \
# 3222     None     大薩瓦納      大薩瓦納
# 3223     None      馬里考       馬里考
#
#                                                geometry  \
# 3222  POLYGON ((-66.88464 18.02481, -66.91089 18.023...
# 3223  POLYGON ((-66.89856 18.18790, -66.86408 18.186...
#
#                      timestamp
# 3222 2022-05-12 00:00:00+00:00
# 3223 2022-05-12 00:00:00+00:00
#
# [2 rows x 63 columns]

# %%
vars(vs)
# Out:
# {'grid': World(4326),
#  'morton': <qtree_index.mortoncurve.Morton at 0x21c58a10390>,
#  'valid_range': <POLYGON ((180 -90, 180 90, -180 90, -180 -90, 180 -90))>,
#  'dataset': 'ne_10m_admin2_counties',
#  'collection_id': 'vector-ne-10m-admin2-counties',
#  'temporal_levels': [],
#  'dimension_values': {},
#  'vectorstore_directory': 'data/vectorstore/',
#  'dataset_directory': 'data/vectorstore/ne_10m_admin2_counties',
#  'grid_directory': 'data/vectorstore/ne_10m_admin2_counties/grid=World(4326)',
#  'geoparquet_directory': 'data/vectorstore/ne_10m_admin2_counties/grid=World(4326)/geoparquet',
#  'index_directory': 'data/vectorstore/ne_10m_admin2_counties/grid=World(4326)/index',
#  'dt_col': 'timestamp',
#  'key_col': '_root',
#  'idx_col': '_idx',
#  'geom_col': 'geometry',
#  'id_col': 'ADM2_CODE',
#  'idx_box_col': 'idx_bounds',
#  'geom_area_col': '_geom_area',
#  'geom_length_col': '_geom_length',
#  'primary_keys': ['timestamp', 'ADM2_CODE'],
#  'max_level': 26,
#  'target_level': 14,
#  'max_depth': 14,
#  'max_inflation': 100,
#  'target_rows': 1000000.0,
#  'row_group_size': 100000.0,
#  'custom_meta_content': {'About': 'Natural Earth (ne) Admin 2 (county-level) data.'},
#  'schema_unified': None,
#  'verbose': True}

# %% [markdown]
# # Chunked successive ingestion

# %%
# %%time
n_chunks = 1
for i, chunk in enumerate(numpy.array_split(gdf_complete, n_chunks)):
    print('Chunk', i)
    vs.partial_upload(
        chunk,
        defrag=False,
        index=False,
        geometry_area=False,
        geometry_length=False,
    )
# Out:
# Chunk 0
# df_root 3224
# Time for indexing the root of each unique geometry in seconds 0.026
# cannot call `vectorize` on size 0 inputs unless `otypes` is set
# Failed to use numpy. Switching to pandas
# distributed over 1 partitions
# Time for creating partitions in seconds 0.037
# Time for writing GeoDataFrame to GeoParquet partitions 0.132
# CPU times: total: 93.8 ms
# Wall time: 166 ms
# C:\Users\2D1245897\software\openeo\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'GeoDataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'GeoDataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\2D1245897\software\openeo\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'GeoDataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'GeoDataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
# %%time
vs.unify_schemas()
# Out:
# Time for unify_schemas 0.058
# CPU times: total: 46.9 ms
# Wall time: 57.5 ms

# %%
# %%time
vs.defrag()
# Out:
# Time for defragging 0.26
# CPU times: total: 125 ms
# Wall time: 260 ms

# %%
# %%time
vs.repartition({})
# Out:
# level 0
# source partition          target partition          records stay    records move
# level 1
# source partition          target partition          records stay    records move
# level 2
# source partition          target partition          records stay    records move
# level 3
# source partition          target partition          records stay    records move
# level 4
# source partition          target partition          records stay    records move
# level 5
# source partition          target partition          records stay    records move
# level 6
# source partition          target partition          records stay    records move
# level 7
# source partition          target partition          records stay    records move
# level 8
# source partition          target partition          records stay    records move
# level 9
# source partition          target partition          records stay    records move
# level 10
# source partition          target partition          records stay    records move
# level 11
# source partition          target partition          records stay    records move
# level 12
# source partition          target partition          records stay    records move
# level 13
# source partition          target partition          records stay    records move
# level 14
# source partition          target partition          records stay    records move
# level 15
# source partition          target partition          records stay    records move
# level 16
# source partition          target partition          records stay    records move
# level 17
# source partition          target partition          records stay    records move
# level 18
# source partition          target partition          records stay    records move
# level 19
# source partition          target partition          records stay    records move
# level 20
# source partition          target partition          records stay    records move
# level 21
# source partition          target partition          records stay    records move
# level 22
# source partition          target partition          records stay    records move
# level 23
# source partition          target partition          records stay    records move
# level 24
# source partition          target partition          records stay    records move
# level 25
# source partition          target partition          records stay    records move
# Time for repartitioning in seconds 0.079
# CPU times: total: 46.9 ms
# Wall time: 81.7 ms

# %%
# %%time
vs.defrag()
# Out:
# Time for defragging 0.166
# CPU times: total: 46.9 ms
# Wall time: 166 ms

# %%
# %%time
# vs.reindex({})

# %% [markdown]
# # Visualize spatial partitions

# %%
# %%time
ddf = dask_geopandas.read_parquet(vs.geoparquet_directory)
ddf
# Out:
# CPU times: total: 15.6 ms
# Wall time: 41.7 ms
# Dask GeoDataFrame Structure:
#               FEATURECLA SCALERANK ADM2_CODE ISO_3166_2  ISO_A2 ADM0_SR    NAME NAME_ALT NAME_LOCAL    TYPE TYPE_EN CODE_LOCAL  REGION REGION_COD  ABBREV AREA_SQKM SAMEASCITY LABELRANK NAME_LEN MAPCOLOR9 MAPCOLOR13    FIPS  SOV_A3 ADM0_A3 ADM0_LABEL   ADMIN GEONUNIT   GU_A3 MIN_LABEL MAX_LABEL MIN_ZOOM WIKIDATAID  NE_ID latitude longitude NAME_AR NAME_BN NAME_DE NAME_EL NAME_EN NAME_ES NAME_FA NAME_FR NAME_HE NAME_HI NAME_HU NAME_ID NAME_IT NAME_JA NAME_KO NAME_NL NAME_PL NAME_PT NAME_RU NAME_SV NAME_TR NAME_UK NAME_UR NAME_VI NAME_ZH NAME_ZHT  geometry            timestamp   _root             grid spatial_partition
# npartitions=1
#                   object     int64    object     object  object   int64  object   object     object  object  object     object  object     object  object   float64      int64     int64    int64     int64      int64  object  object  object      int64  object   object  object     int64     int64  float64     object  int64  float64   float64  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object  object   object  geometry  datetime64[us, UTC]  object  category[known]   category[known]
#                      ...       ...       ...        ...     ...     ...     ...      ...        ...     ...     ...        ...     ...        ...     ...       ...        ...       ...      ...       ...        ...     ...     ...     ...        ...     ...      ...     ...       ...       ...      ...        ...    ...      ...       ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...      ...       ...                  ...     ...              ...               ...
# Dask Name: read-parquet, 1 graph layer

# %%
ddf.spatial_partitions.plot(edgecolor='k', alpha=0.3)
# Out:
# <Axes: >

# %% [markdown]
# # Upload to COS and register in STAC

# %%
import dotenv
dotenv.load_dotenv()

# S3 access key
access_key_id = os.getenv('claimed_access_key_id', '')
# S3 access secret
secret_access_key = os.getenv('claimed_secret_access_key', '')
# S3 access url
endpoint_url = os.getenv('claimed_endpoint_url', '')
# S3 access url
private_endpoint_url = os.getenv('claimed_private_endpoint_url', '')
# S3 bucket
bucket = os.getenv('claimed_bucket', '')

# STAC url
stac_url = os.getenv('stac_url', 'https://stac-fastapi-pgstac-nasageospatial-dev.cash.sl.cloud9.ibm.com')
# STAC certificate
certificate = os.getenv('certificate', '/opt/app-root/src/ca.cert.txt')

#vs._connect_s3(access_key_id, secret_access_key, endpoint_url, bucket)

# %%
# vs.access_key_id = access_key_id
# vs.secret_access_key = secret_access_key
# vs.endpoint_url = endpoint_url
# vs.bucket = bucket
# vs._connect_s3(access_key_id, secret_access_key, endpoint_url, bucket)

# storage_urls = vs.remote_fs.glob(os.path.join(vs.remote_geoparquet_directory, '**.parquet').replace('\\', '/'))
# storage_urls

# %%
# # GeoDN username
# geodn_username = os.getenv('geodn_username', '')
# # GeoDN password
# geodn_password = os.getenv('geodn_password', '')
# # GeoDN url
# GEODN_URL = os.getenv('GEODN_URL', "https://openeo-geodn-nasageospatial-dev.cash.sl.cloud9.ibm.com/openeo/1.1.0/")

# %%
stac_json_folder = os.path.join(vs.grid_directory, 'stac').replace('\\','/')

bbox = vs.grid.valid_bounds_wgs84
df = pandas.read_parquet(vs.geoparquet_directory, columns=[vs.dt_col])
dt_start = df[vs.dt_col].min()
dt_end = df[vs.dt_col].max()

vs.to_stac_collection(
    stac_url,
    vs.collection_id,
    collection_title,
    stac_json_folder,
    certificate,
    bbox,
    dt_start,
    dt_end,
    description,
    access_key_id=access_key_id,
    secret_access_key=secret_access_key,
    endpoint_url=endpoint_url,
    bucket=bucket,
    remote_vectorstore_directory=None,
)

# %%
# %%time
# Upload to COS
upload_type = "replace_all" #"replace_all" "replace_partition" "add" "stac_items_only"
vs.to_cos(
    upload_type=upload_type,
    stac_url=stac_url,
    collection_id=vs.collection_id,
    collection_title=collection_title,
    stac_json_folder=stac_json_folder,
    certificate=certificate,
    access_key_id=access_key_id,
    secret_access_key=secret_access_key,
    endpoint_url=endpoint_url,
    bucket=bucket,
    remote_vectorstore_directory=None,
    temporal_partitions=None,
    spatial_partitions=None,
)
# Out:
# uploading to remote_path claimed-test/vectorstore/ne_10m_admin2_counties/grid=World(4326)/geoparquet/spatial_partition=0q/dcdebf636af344dfafd619b9bc6f047d.parquet
# schema.names ['FEATURECLA', 'SCALERANK', 'ADM2_CODE', 'ISO_3166_2', 'ISO_A2', 'ADM0_SR', 'NAME', 'NAME_ALT', 'NAME_LOCAL', 'TYPE', 'TYPE_EN', 'CODE_LOCAL', 'REGION', 'REGION_COD', 'ABBREV', 'AREA_SQKM', 'SAMEASCITY', 'LABELRANK', 'NAME_LEN', 'MAPCOLOR9', 'MAPCOLOR13', 'FIPS', 'SOV_A3', 'ADM0_A3', 'ADM0_LABEL', 'ADMIN', 'GEONUNIT', 'GU_A3', 'MIN_LABEL', 'MAX_LABEL', 'MIN_ZOOM', 'WIKIDATAID', 'NE_ID', 'latitude', 'longitude', 'NAME_AR', 'NAME_BN', 'NAME_DE', 'NAME_EL', 'NAME_EN', 'NAME_ES', 'NAME_FA', 'NAME_FR', 'NAME_HE', 'NAME_HI', 'NAME_HU', 'NAME_ID', 'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL', 'NAME_PL', 'NAME_PT', 'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_UK', 'NAME_UR', 'NAME_VI', 'NAME_ZH', 'NAME_ZHT', 'geometry', 'timestamp', '_root']
# schema.types [DataType(string), DataType(int64), DataType(string), DataType(string), DataType(string), DataType(int64), DataType(string), DataType(string), DataType(null), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(null), DataType(double), DataType(int64), DataType(int64), DataType(int64), DataType(int64), DataType(int64), DataType(string), DataType(string), DataType(string), DataType(int64), DataType(string), DataType(string), DataType(string), DataType(int64), DataType(int64), DataType(double), DataType(string), DataType(int64), DataType(double), DataType(double), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(string), DataType(binary), TimestampType(timestamp[us, tz=UTC]), DataType(string)]
# schema.metadata [b'ne_10m_admin2_counties', b'pandas', b'geo']
# Time for pushing local vectorstore to COS 5.011
# CPU times: total: 188 ms
# Wall time: 5.01 s

# %%
vs.stac_json_folder_submitted
# Out:
# 'data/vectorstore/ne_10m_admin2_counties/grid=World(4326)/stac/submitted'

# %%
vs.stac_url
# Out:
# 'https://stac-fastapi-sqlalchemy-nasageospatial-dev.cash.sl.cloud9.ibm.com'

# %%
vs.collection_id
# Out:
# 'vector-ne-10m-admin2-counties'
