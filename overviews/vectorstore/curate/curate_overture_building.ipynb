# %%
# aws s3 cp --region us-west-2 --no-sign-request --recursive s3://overturemaps-us-west-2/release/2024-08-20.0/theme=buildings .

# %%
import os
os.environ['USE_PYGEOS'] = '0'

import numpy
import pandas
from datetime import datetime, timedelta
import pytz
import geopandas
import dask_geopandas
import shapely
from shapely import wkb, wkt
import pyproj

import subprocess
import shutil
from glob import glob
import json

from functools import partial
from multiprocessing import Pool
from random import shuffle

import matplotlib.pyplot as plt

# %%
raw_geoparquet_path = '/data/raster/overture/building_raw'
processed_geoparquet_path = '/data/raster/overture/building_processed'
files = glob(os.path.join(raw_geoparquet_path, '**/*.parquet'))
len(files)
# Out:
# 209

# %%
class NpEncoder(json.JSONEncoder):
    # To avoid json type errors
    def default(self, obj):
        if isinstance(obj, numpy.integer):
            return int(obj)
        if isinstance(obj, numpy.floating):
            return float(obj)
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)
        
def _split_names(names_dict, cols):
    """Split names dictionaries into those we want to extract as columns and those we want to keep as json."""
    explode_cols = ['primary']
    explode_names = {x: names_dict[x] for x in names_dict if x in explode_cols and (names_dict[x] is not None)}
    other_names = {x: names_dict[x] for x in names_dict if (x not in explode_cols) and (names_dict[x] is not None)}
    
    return explode_names, other_names

def _names_to_columns(gdf, cols):
    """Extract the primary name from names and move the remaining ones to other_names."""
    if len(gdf)>0:
        # Split names json dictionaries into those we want to extract as columns and those we want to keep as json.
        gdf[['explode_names', 'other_names']] = gdf['names'].apply(lambda x: _split_names(x, cols)).to_list()
        
        # Convert explode_names to columns
        gdf_tmp = pandas.DataFrame(gdf['explode_names'].to_list())
        other_cols = sorted(set(gdf.columns) - set(gdf_tmp.columns) - set(['names', 'explode_names']))
        gdf = pandas.concat([gdf_tmp, gdf[other_cols]], axis=1)
        
        # Dumping other_names to json string so that the column can be saved efficiently in parquet
        gdf['other_names'] = gdf['other_names'].apply(lambda x: json.dumps(x, cls=NpEncoder))
        
    return geopandas.GeoDataFrame(gdf)

# %%
cols = []
for file in files:
    gdf = geopandas.read_parquet(
        file,
        filters=[('version', '!=', 0)]
    )
    if len(gdf)>0:
        print(file)
    cols.extend(list(gdf.columns))
cols = sorted(set(cols))

exclude_cols = [
    'bbox',
    'version', 
    'names',
]

include_cols = [
    'id', 
    'release_time',
    'name',
    'sources',
    'type', 
    'subtype',
    'class',
    'level',
    'has_parts',
    'building_id',
    'height',
    'is_underground',
    'num_floors',
    'num_floors_underground',
    'min_height',
    'min_floor',
    'facade_color',
    'facade_material',
    'roof_material',
    'roof_shape',
    'roof_direction',
    'roof_orientation',
    'roof_color',
    'roof_height', 
    'geometry', 
]

print('Removing these columns:', set(exclude_cols))
print('Adding these columns:  ', (set(exclude_cols) | set(include_cols)) - set(cols))
assert len(set(cols) - (set(exclude_cols) | set(include_cols)))==0
# Out:
# Removing these columns: {'names', 'version', 'bbox'}
# Adding these columns:   {'type', 'name', 'release_time'}

# %%
for file in files:
    file = file.replace('\\', '/')
    print(file)
    gdf = geopandas.read_parquet(file)
    
    gdf['release_time'] = datetime(2024, 8, 20, tzinfo=pytz.utc)
    
    # Get the hive-style "type" column value
    gdf['type'] = os.path.split(os.path.split(file)[0])[1].split('type=')[1]
    
    if 'names' in gdf.columns:
        # Replace None with empty dictionary
        gdf[['names']]=gdf[['names']].map(lambda x: {} if pandas.isnull(x) else x)
        
        # Extract the primary name
        gdf = _names_to_columns(gdf, 'names')
        gdf = gdf.rename(columns={'primary': 'name'})
    
    # Common set of columns for all parquet files
    for col in exclude_cols:
        if col in gdf.columns:
            del gdf[col]
    for col in include_cols:
        if col not in gdf.columns:
            gdf[col] = None
    gdf = gdf[include_cols]
    
    # Dumping some columns to json string so that the column can be saved efficiently in parquet
    gdf['sources'] = gdf['sources'].apply(lambda x: json.dumps(x, cls=NpEncoder))
    
    # Write to file
    out_path = os.path.join(
        processed_geoparquet_path, 
        file.split(raw_geoparquet_path+'/')[1]
    ).replace('\\', '/')
    out_dir = os.path.split(out_path)[0]
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    gdf.to_parquet(out_path)
# Out:
# /data/raster/overture/building_raw/type=building/part-00000-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00001-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00002-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00003-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00004-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00005-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00006-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00007-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00008-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00009-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00010-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00011-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00012-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00013-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00014-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00015-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00016-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00017-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00018-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00019-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00020-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00021-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00022-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00023-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00024-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00025-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00026-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00027-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00028-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00029-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00030-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00031-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00032-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00033-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00034-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00035-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00036-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00037-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00038-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00039-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00040-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00041-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00042-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00043-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00044-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00045-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00046-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00047-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00048-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00049-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00050-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00051-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00052-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00053-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00054-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00055-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00056-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00057-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00058-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00059-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00060-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00061-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00062-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00063-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00064-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00065-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00066-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00067-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00068-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00069-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00070-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00071-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00072-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00073-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00074-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00075-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00076-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00077-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00078-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00079-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00080-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00081-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00082-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00083-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00084-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00085-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00086-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00087-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00088-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00089-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00090-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00091-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00092-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00093-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00094-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00095-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00096-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00097-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00098-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00099-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00100-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00101-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00102-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00103-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00104-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00105-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00106-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00107-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00108-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00109-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00110-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00111-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00112-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00113-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00114-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00115-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00116-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00117-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00118-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00119-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00120-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00121-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00122-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00123-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00124-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00125-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00126-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00127-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00128-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00129-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00130-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00131-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00132-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00133-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00134-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00135-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00136-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00137-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00138-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00139-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00140-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00141-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00142-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00143-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00144-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00145-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00146-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00147-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00148-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00149-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00150-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00151-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00152-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00153-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00154-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00155-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00156-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00157-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00158-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00159-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00160-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00161-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00162-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00163-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00164-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00165-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00166-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00167-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00168-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00169-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00170-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00171-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00172-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00173-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00174-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00175-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00176-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00177-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00178-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00179-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00180-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00181-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00182-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00183-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00184-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00185-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00186-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00187-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00188-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00189-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00190-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00191-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00192-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00193-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00194-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00195-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00196-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00197-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00198-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00199-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00200-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00201-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00202-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00203-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00204-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00205-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00206-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building/part-00207-2ad9544f-1d68-4a5a-805c-7a5d020d084d-c000.zstd.parquet
# /data/raster/overture/building_raw/type=building_part/part-00000-a8096b90-9429-4428-b8bc-0bdc44e1edc8-c000.zstd.parquet

# %%
dask_geopandas.read_parquet(processed_geoparquet_path, split_row_groups=False)
# Out:
# Dask GeoDataFrame Structure:
#                      id         release_time    name sources             type subtype   class    level has_parts building_id   height is_underground num_floors num_floors_underground min_height min_floor facade_color facade_material roof_material roof_shape roof_direction roof_orientation roof_color roof_height  geometry
# npartitions=209
#                  object  datetime64[us, UTC]  object  object  category[known]  object  object  float64      bool      object  float64           bool    float64                float64    float64   float64       object          object        object     object        float64           object     object     float64  geometry
#                     ...                  ...     ...     ...              ...     ...     ...      ...       ...         ...      ...            ...        ...                    ...        ...       ...          ...             ...           ...        ...            ...              ...        ...         ...       ...
# ...                 ...                  ...     ...     ...              ...     ...     ...      ...       ...         ...      ...            ...        ...                    ...        ...       ...          ...             ...           ...        ...            ...              ...        ...         ...       ...
#                     ...                  ...     ...     ...              ...     ...     ...      ...       ...         ...      ...            ...        ...                    ...        ...       ...          ...             ...           ...        ...            ...              ...        ...         ...       ...
#                     ...                  ...     ...     ...              ...     ...     ...      ...       ...         ...      ...            ...        ...                    ...        ...       ...          ...             ...           ...        ...            ...              ...        ...         ...       ...
# Dask Name: read-parquet, 1 graph layer
